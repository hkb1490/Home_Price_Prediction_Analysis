# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score

# %%
cd C:\Users\Yamini\Desktop\FT\Python projects\Python Linear Regression Project 2_Home Price Prediction Analysis
# Out:
# C:\Users\Yamini\Desktop\FT\Python projects\Python Linear Regression Project 2_Home Price Prediction Analysis

# %%
data = pd.read_csv("Python_Linear_Regres.csv")
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
new_data = data.drop(['Address', 'Date','Postcode','Lattitude','Longtitude','YearBuilt'], axis = 1)
new_data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
new_data.describe()
# Out:
#               Rooms         Price      Distance      Bedroom2      Bathroom  \
# count  34857.000000  2.724700e+04  34856.000000  26640.000000  26631.000000
# mean       3.031012  1.050173e+06     11.184929      3.084647      1.624798
# std        0.969933  6.414671e+05      6.788892      0.980690      0.724212
# min        1.000000  8.500000e+04      0.000000      0.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000      2.000000      1.000000
# 50%        3.000000  8.700000e+05     10.300000      3.000000      2.000000
# 75%        4.000000  1.295000e+06     14.000000      4.000000      2.000000
# max       16.000000  1.120000e+07     48.100000     30.000000     12.000000
#
#                 Car       Landsize  BuildingArea  Propertycount
# count  26129.000000   23047.000000   13742.00000   34854.000000
# mean       1.728845     593.598993     160.25640    7572.888306
# std        1.010771    3398.841946     401.26706    4428.090313
# ...

# %%
new_data.dtypes
# Out:
# Suburb            object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Distance         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# CouncilArea       object
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
new_data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
new_data[['Propertycount','Distance','Bedroom2','Car','Bathroom']] = 
new_data[['Propertycount','Distance','Bedroom2','Car','Bathroom']].fillna(0)
# Out:
#   File "C:\Users\Yamini\AppData\Local\Temp\ipykernel_12252\2486786686.py", line 1
#     new_data[['Propertycount','Distance','Bedroom2','Car','Bathroom']] =
#                                                                          ^
# SyntaxError: invalid syntax

# %%
new_data['Propertycount'] = new_data['Propertycount'].fillna(0)
new_data['Car'] = new_data['Car'].fillna(0)
new_data['Distance'] = new_data['Distance'].fillna(0)
new_data['Bedroom2'] = new_data['Bedroom2'].fillna(0)
new_data['Bathroom'] = new_data['Bathroom'].fillna(0)

# %%
new_data['Landsize'] = new_data['Landsize'].fillna(new_data['Landsize'].mean())
new_data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
new_data['BuildingArea'] = new_data['BuildingArea'].fillna(new_data['BuildingArea'].mean())
new_data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
new_data.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# CouncilArea         3
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
9) Create a dummy data for categorical data

# %%
new_data['Method'].unique()
# Out:
# array(['SS', 'S', 'VB', 'SP', 'PI', 'SN', 'W', 'PN', 'SA'], dtype=object)

# %%
new_data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
Create the target data and feature data where target data is price
2) Create a linear regression model for Target and feature data
3) Check if the model is overfitting or underfitting or it is accurate
4) If the model is overfitting then apply ridge and lasso regression algorithms
5) Extract slope and intercept value from the model
6) Display Mean Squared Error
7) Display Mean Absolute Error
8) Display Root mean Squared error
9) Display R2 score

# %%
new_data.shape
# Out:
# (34857, 15)

# %%
X = new_data.drop('Price', axis = 1)
y = new_data['Price']

# %%
X.head()
# Out:
#        Suburb  Rooms Type Method SellerG  Distance  Bedroom2  Bathroom  Car  \
# 0  Abbotsford      2    h     SS  Jellis       2.5       2.0       1.0  1.0
# 1  Abbotsford      2    h      S  Biggin       2.5       2.0       1.0  1.0
# 2  Abbotsford      2    h      S  Biggin       2.5       2.0       1.0  0.0
# 3  Abbotsford      3    u     VB  Rounds       2.5       3.0       2.0  1.0
# 4  Abbotsford      3    h     SP  Biggin       2.5       3.0       2.0  0.0
#
#    Landsize  BuildingArea         CouncilArea             Regionname  \
# 0     126.0      160.2564  Yarra City Council  Northern Metropolitan
# 1     202.0      160.2564  Yarra City Council  Northern Metropolitan
# 2     156.0       79.0000  Yarra City Council  Northern Metropolitan
# 3       0.0      160.2564  Yarra City Council  Northern Metropolitan
# 4     134.0      150.0000  Yarra City Council  Northern Metropolitan
#
#    Propertycount
# 0         4019.0
# 1         4019.0
# 2         4019.0
# 3         4019.0
# ...

# %%
y.shape
# Out:
# (34857,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train
# Out:
#                Suburb  Rooms Type Method        SellerG  Distance  Bedroom2  \
# 32183     Templestowe      4    h     SP          Barry      15.5       4.0
# 10801         Windsor      2    u      S  hockingstuart       5.1       2.0
# 4742          Glenroy      3    h      S          Barry      13.0       0.0
# 25089       Glen Iris      4    h      S         Jellis       7.3       4.0
# 29441  Doncaster East      4    h      S  hockingstuart      14.3       4.0
# ...               ...    ...  ...    ...            ...       ...       ...
# 33508        McKinnon      4    t     PN           Gary      11.4       0.0
# 33800   Sunshine West      3    t     PI        Douglas      10.5       3.0
# 5520       Hughesdale      4    h      S            Ray      13.0       4.0
# 20463          Coburg      3    h     SP         Nelson       6.7       3.0
# 18638        Mulgrave      5    h      S            Ray      18.8       5.0
#
# ...

# %%
X_train.shape
# Out:
# (27885, 14)

# %%
len(X_train)
# Out:
# 27885

# %%
X_test
# Out:
#                 Suburb  Rooms Type Method        SellerG  Distance  Bedroom2  \
# 17184  North Melbourne      3    h     PI              J       1.8       3.0
# 25173        Kurunjang      3    h     SP  PRDNationwide      31.7       3.0
# 11046   Brunswick East      3    h     SP         Jellis       4.5       3.0
# 2371    Brunswick West      2    h     SP  hockingstuart       5.9       2.0
# 30606        Moorabbin      3    t     SP         Buxton      14.3       3.0
# ...                ...    ...  ...    ...            ...       ...       ...
# 2862        Canterbury      2    h     VB         Jellis       9.0       2.0
# 19882           Coburg      2    t      S           Brad       6.7       2.0
# 9120   South Melbourne      2    h     SN         Cayzer       2.1       2.0
# 11696           Ormond      3    t      S  hockingstuart      11.8       3.0
# 9489          St Kilda      2    u      S         Wilson       6.1       2.0
#
# ...

# %%
X_test.shape
# Out:
# (6972, 14)

# %%
len(X_test)
# Out:
# 6972

# %%
y_train
# Out:
# 32183    1475000.0
# 10801     518000.0
# 4742      681500.0
# 25089          NaN
# 29441    1198000.0
#            ...
# 33508          NaN
# 33800     535000.0
# 5520     1337000.0
# 20463    1010000.0
# 18638     960000.0
# Name: Price, Length: 27885, dtype: float64

# %%
y_test
# Out:
# 17184    1285000.0
# 25173     380000.0
# 11046    1350000.0
# 2371      900000.0
# 30606     960000.0
#            ...
# 2862     1800000.0
# 19882     631000.0
# 9120           NaN
# 11696    1250000.0
# 9489      500000.0
# Name: Price, Length: 6972, dtype: float64

# %%
y_train.shape
# Out:
# (27885,)

# %%
y_test.shape
# Out:
# (6972,)

# %%
len(y_train)
# Out:
# 27885

# %%
len(y_test)
# Out:
# 6972

# %%
from sklearn.linear_model import LinearRegression

# %%
regression_model = LinearRegression()

# %%
regression_model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12252\4267044707.py in <module>
# ----> 1 regression_model.fit(X_train,y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
